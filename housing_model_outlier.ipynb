# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations
from sklearn.model_selection import KFold

# %%
df= pd.read_csv('data/kc_house_data.csv')
corr=df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df=df[['price','sqft_living','bedrooms','bathrooms','floors','grade','condition','yr_built','yr_renovated','waterfront']]
df
# Out:
#           price  sqft_living  bedrooms  bathrooms  floors  grade  condition  \
# 0      221900.0         1180         3       1.00     1.0      7          3
# 1      538000.0         2570         3       2.25     2.0      7          3
# 2      180000.0          770         2       1.00     1.0      6          3
# 3      604000.0         1960         4       3.00     1.0      7          5
# 4      510000.0         1680         3       2.00     1.0      8          3
# ...         ...          ...       ...        ...     ...    ...        ...
# 21592  360000.0         1530         3       2.50     3.0      8          3
# 21593  400000.0         2310         4       2.50     2.0      8          3
# 21594  402101.0         1020         2       0.75     2.0      7          3
# 21595  400000.0         1600         3       2.50     2.0      8          3
# 21596  325000.0         1020         2       0.75     2.0      7          3
#
#        yr_built  yr_renovated  waterfront
# 0          1955           0.0         NaN
# 1          1951        1991.0         0.0
# 2          1933           NaN         0.0
# 3          1965           0.0         0.0
# 4          1987           0.0         0.0
# ...         ...           ...         ...
# 21592      2009           0.0         0.0
# 21593      2014           0.0         0.0
# 21594      2009           0.0         0.0
# 21595      2004           0.0         NaN
# 21596      2008           0.0         0.0
#
# [21597 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# price              0
# sqft_living        0
# bedrooms           0
# bathrooms          0
# floors             0
# grade              0
# condition          0
# yr_built           0
# yr_renovated    3842
# waterfront      2376
# dtype: int64

# %%
df['waterfront'] = df['waterfront'].fillna(0)

# %%
df.isnull().sum()
df['yr_renovated'] = df['yr_renovated'].fillna(0)
df.isnull().sum()
# Out:
# price           0
# sqft_living     0
# bedrooms        0
# bathrooms       0
# floors          0
# grade           0
# condition       0
# yr_built        0
# yr_renovated    0
# waterfront      0
# dtype: int64

# %%
df.rename(columns={'yr_renovated': 'renovated'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21597 non-null  float64
#  1   sqft_living  21597 non-null  int64
#  2   bedrooms     21597 non-null  int64
#  3   bathrooms    21597 non-null  float64
#  4   floors       21597 non-null  float64
#  5   grade        21597 non-null  int64
#  6   condition    21597 non-null  int64
#  7   yr_built     21597 non-null  int64
#  8   renovated    21597 non-null  float64
#  9   waterfront   21597 non-null  float64
# dtypes: float64(5), int64(5)
# memory usage: 1.6 MB

# %%
df['age'] = 2015 - df.yr_built
df = df.drop(columns=['yr_built'], axis=1)

# %%
renovated = df.renovated.values
age = df.age.values
values = np.where(renovated <= 10, 1, 0)
df['renovated'] = np.where(age <= 5, 1, values)

# %%
value_counts_bed=df['bedrooms'].value_counts()
to_remove = value_counts_bed[value_counts_bed <=50].index
df = df[~df.bedrooms.isin(to_remove)]

# %%
value_counts_bath=df['bathrooms'].value_counts()
to_remove_bath = value_counts_bath[value_counts_bath <=80].index
df = df[~df.bathrooms.isin(to_remove_bath)]

# %%
value_counts_floors=df['floors'].value_counts()
to_remove_floor = value_counts_floors[value_counts_floors <=10].index
df = df[~df.floors.isin(to_remove_floor)]

# %%
df.head()
# Out:
#       price  sqft_living  bedrooms  bathrooms  floors  grade  condition  \
# 0  221900.0         1180         3       1.00     1.0      7          3
# 1  538000.0         2570         3       2.25     2.0      7          3
# 2  180000.0          770         2       1.00     1.0      6          3
# 3  604000.0         1960         4       3.00     1.0      7          5
# 4  510000.0         1680         3       2.00     1.0      8          3
#
#    renovated  waterfront  age
# 0          1         0.0   60
# 1          0         0.0   64
# 2          1         0.0   82
# 3          1         0.0   50
# 4          1         0.0   28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21291 entries, 0 to 21595
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21291 non-null  float64
#  1   sqft_living  21291 non-null  int64
#  2   bedrooms     21291 non-null  int64
#  3   bathrooms    21291 non-null  float64
#  4   floors       21291 non-null  float64
#  5   grade        21291 non-null  int64
#  6   condition    21291 non-null  int64
#  7   renovated    21291 non-null  int32
#  8   waterfront   21291 non-null  float64
#  9   age          21291 non-null  int64
# dtypes: float64(4), int32(1), int64(5)
# memory usage: 1.7 MB

# %%
df[['bedrooms', 'bathrooms', 'floors', 'age','renovated','grade','waterfront','sqft_living']].hist(figsize  = [6, 6]);

# %%
ax = sns.boxplot(x="price", data=df)

# %%
plt.scatter(df['bedrooms'], df['price'], color='green')
plt.title('Bedrooms and Price', fontsize=14)
plt.xlabel('Number of Bedrooms', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
sns.jointplot(data=df, x="bedrooms", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="grade", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="bathrooms", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="floors", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="age", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="renovated", y="price", kind="reg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-811369c24e31> in <module>
# ----> 1 sns.jointplot(data=df, x="renovated", y="price", kind="reg")
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2054
#    2055     # Initialize the JointGrid object
# -> 2056     grid = JointGrid(
#    2057         data=data, x=x, y=y, hue=hue,
#    2058         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size, marginal_ticks, hue, palette, hue_order, hue_norm)
#    1589
#    1590         # Process the input variables
# -> 1591         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1592         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1593
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     885                     # We don't know what this name means
#     886                     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 887                     raise ValueError(err)
#     888
#     889             else:
#
# ValueError: Could not interpret value `renovated` for parameter `x`

# %%
plt.scatter(df['bathrooms'], df['price'], color='blue')
plt.title('Bathrooms and Price', fontsize=14)
plt.xlabel('Number of Bathrooms', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['floors'], df['price'], color='red')
plt.title('Floors and Price', fontsize=14)
plt.xlabel('Number of Floors', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['age'], df['price'], color='orange')
plt.title('House Age and Price', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Model 1

# %%
def tts_model(df):
    y = df['price']
    X = df.drop(columns=['price'], axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=123)
    
    linreg = LinearRegression()
    model = linreg.fit(X_train, y_train)

    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)

    mse_train = mean_squared_error(y_train, train_predictions)
    mse_test = mean_squared_error(y_test, test_predictions)
    
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)

    print('Mean Squared Error Test:', np.sqrt(mse_test))
    print('Mean Squared Error Train:', np.sqrt(mse_train))
    print('Training Score:', round(train_score, 2))
    print('Test Score:', round(test_score, 2))
    print('Coefficients:', model.coef_)

    X_train = sm.add_constant(X_train)
    smmodel = sm.OLS(y_train, X_train).fit()
    print(smmodel.summary())
    return smmodel

# %%
model = tts_model(df)

# %%
plt.figure(figsize=(12, 8))
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)
plt.title('QQ Plot')
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df.price)
plt.title('Price Distribution')
plt.tight_layout()

# %%
df = df[df['price'] <= 1100000]

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df.price)
plt.title('Price Distribution')
plt.tight_layout()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20234 entries, 0 to 21595
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        20234 non-null  float64
#  1   sqft_living  20234 non-null  int64
#  2   bedrooms     20234 non-null  int64
#  3   bathrooms    20234 non-null  float64
#  4   floors       20234 non-null  float64
#  5   grade        20234 non-null  int64
#  6   condition    20234 non-null  int64
#  7   renovated    20234 non-null  int32
#  8   waterfront   20234 non-null  float64
#  9   age          20234 non-null  int64
# dtypes: float64(4), int32(1), int64(5)
# memory usage: 1.6 MB

# %%
model = tts_model(df)
# Out:
# Mean Squared Error Test: 133472.6548588853
# Mean Squared Error Train: 137354.70694855522
# Training Score: 0.55
# Test Score: 0.58
# Coefficients: [ 8.94699879e+01 -1.79280636e+04  3.23534154e+04  3.79192140e+04
#   1.01942009e+05  1.77925303e+04 -1.22632259e+04  1.90542816e+05
#   2.69576194e+03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     2238.
# Date:                Thu, 08 Jul 2021   Prob (F-statistic):               0.00
# Time:                        09:03:53   Log-Likelihood:            -2.1447e+05
# No. Observations:               16187   AIC:                         4.290e+05
# Df Residuals:                   16177   BIC:                         4.290e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -6.989e+05   1.51e+04    -46.341      0.000   -7.28e+05   -6.69e+05
# sqft_living    89.4700      2.615     34.216      0.000      84.345      94.595
# bedrooms    -1.793e+04   1631.918    -10.986      0.000   -2.11e+04   -1.47e+04
# bathrooms    3.235e+04   2648.327     12.217      0.000    2.72e+04    3.75e+04
# floors       3.792e+04   2541.354     14.921      0.000    3.29e+04    4.29e+04
# grade        1.019e+05   1647.015     61.895      0.000    9.87e+04    1.05e+05
# condition    1.779e+04   1831.766      9.713      0.000    1.42e+04    2.14e+04
# renovated   -1.226e+04   6588.675     -1.861      0.063   -2.52e+04     651.306
# waterfront   1.905e+05   2.36e+04      8.057      0.000    1.44e+05    2.37e+05
# age          2695.7619     52.591     51.259      0.000    2592.678    2798.846
# ==============================================================================
# Omnibus:                      664.044   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              895.136
# Skew:                           0.421   Prob(JB):                    4.20e-195
# Kurtosis:                       3.786   Cond. No.                     4.62e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.62e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)
plt.title('QQ Plot')
plt.show()

# %% [markdown]
# ## Multicollinearity

# %%
X = df.drop(columns=['price'], axis=1)
plt.figure(figsize=(14, 10))
sns.heatmap(X.corr(), center=0)
plt.tight_layout()
plt.show()

# %%
abs(X.corr()) >= .7
# Out:
#              sqft_living  bedrooms  bathrooms  floors  grade  condition  \
# sqft_living         True     False       True   False   True      False
# bedrooms           False      True      False   False  False      False
# bathrooms           True     False       True   False  False      False
# floors             False     False      False    True  False      False
# grade               True     False      False   False   True      False
# condition          False     False      False   False  False       True
# renovated          False     False      False   False  False      False
# waterfront         False     False      False   False  False      False
# age                False     False      False   False  False      False
#
#              renovated  waterfront    age
# sqft_living      False       False  False
# bedrooms         False       False  False
# bathrooms        False       False  False
# floors           False       False  False
# grade            False       False  False
# condition        False       False  False
# renovated         True       False  False
# waterfront       False        True  False
# age              False       False   True

# %%
corr_df = X.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# Zip the variable name columns in a  column named "pairs"
corr_df['pairs'] = list(zip(corr_df.level_0, corr_df.level_1))

# Set index to pairs
corr_df.set_index(['pairs'], inplace = True)

# Drop level columns
corr_df.drop(columns=['level_1', 'level_0'], inplace = True)

# Rename correlation column to cc
corr_df.columns = ['cc']

# Drop duplicates
corr_df.drop_duplicates(inplace=True)

# %%
corr_df[(corr_df.cc>.70) & (corr_df.cc <1)]
# Out:
#                                 cc
# pairs
# (bathrooms, sqft_living)  0.709345
# (grade, sqft_living)      0.703066

# %%
X = sm.add_constant(X)
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_dict = dict(zip(X.columns, vif))
vif_dict
# Out:
# {'const': 195.12252555428915,
#  'sqft_living': 3.356338598777108,
#  'bedrooms': 1.6656885728619628,
#  'bathrooms': 2.8663869060821763,
#  'floors': 1.594182041543494,
#  'grade': 2.4351410494492076,
#  'condition': 1.2040407858340867,
#  'renovated': 1.0973891752458727,
#  'waterfront': 1.0050124000808927,
#  'age': 2.0076211218546884}

# %%
tts_model(df)
# Out:
# Mean Squared Error Test: 133472.6548588853
# Mean Squared Error Train: 137354.70694855522
# Training Score: 0.55
# Test Score: 0.58
# Coefficients: [ 8.94699879e+01 -1.79280636e+04  3.23534154e+04  3.79192140e+04
#   1.01942009e+05  1.77925303e+04 -1.22632259e+04  1.90542816e+05
#   2.69576194e+03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     2238.
# Date:                Thu, 08 Jul 2021   Prob (F-statistic):               0.00
# Time:                        09:03:55   Log-Likelihood:            -2.1447e+05
# No. Observations:               16187   AIC:                         4.290e+05
# Df Residuals:                   16177   BIC:                         4.290e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -6.989e+05   1.51e+04    -46.341      0.000   -7.28e+05   -6.69e+05
# sqft_living    89.4700      2.615     34.216      0.000      84.345      94.595
# bedrooms    -1.793e+04   1631.918    -10.986      0.000   -2.11e+04   -1.47e+04
# bathrooms    3.235e+04   2648.327     12.217      0.000    2.72e+04    3.75e+04
# floors       3.792e+04   2541.354     14.921      0.000    3.29e+04    4.29e+04
# grade        1.019e+05   1647.015     61.895      0.000    9.87e+04    1.05e+05
# condition    1.779e+04   1831.766      9.713      0.000    1.42e+04    2.14e+04
# renovated   -1.226e+04   6588.675     -1.861      0.063   -2.52e+04     651.306
# waterfront   1.905e+05   2.36e+04      8.057      0.000    1.44e+05    2.37e+05
# age          2695.7619     52.591     51.259      0.000    2592.678    2798.846
# ==============================================================================
# Omnibus:                      664.044   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              895.136
# Skew:                           0.421   Prob(JB):                    4.20e-195
# Kurtosis:                       3.786   Cond. No.                     4.62e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.62e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df = df.drop(columns=['renovated'], axis=1)

# %%
tts_model(df)
# Out:
# Mean Squared Error Test: 133407.64611792433
# Mean Squared Error Train: 137369.41332308095
# Training Score: 0.55
# Test Score: 0.58
# Coefficients: [ 8.95074063e+01 -1.80509062e+04  3.29481258e+04  3.81152031e+04
#   1.01967865e+05  1.73309268e+04  1.92544523e+05  2.72326633e+03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     2517.
# Date:                Thu, 08 Jul 2021   Prob (F-statistic):               0.00
# Time:                        09:03:55   Log-Likelihood:            -2.1447e+05
# No. Observations:               16187   AIC:                         4.290e+05
# Df Residuals:                   16178   BIC:                         4.290e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -7.118e+05   1.34e+04    -53.139      0.000   -7.38e+05   -6.86e+05
# sqft_living    89.5074      2.615     34.229      0.000      84.382      94.633
# bedrooms    -1.805e+04   1630.707    -11.069      0.000   -2.12e+04   -1.49e+04
# bathrooms    3.295e+04   2629.181     12.532      0.000    2.78e+04    3.81e+04
# floors       3.812e+04   2539.365     15.010      0.000    3.31e+04    4.31e+04
# grade         1.02e+05   1647.082     61.908      0.000    9.87e+04    1.05e+05
# condition    1.733e+04   1815.038      9.549      0.000    1.38e+04    2.09e+04
# waterfront   1.925e+05   2.36e+04      8.150      0.000    1.46e+05    2.39e+05
# age          2723.2663     50.476     53.952      0.000    2624.328    2822.204
# ==============================================================================
# Omnibus:                      667.858   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              900.697
# Skew:                           0.423   Prob(JB):                    2.61e-196
# Kurtosis:                       3.788   Cond. No.                     4.61e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.61e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)
plt.title('QQ Plot')
plt.show()

# %% [markdown]
# Interactions

# %%
y = df['price']
X = df.drop(columns=['price'], axis=1)
regression = LinearRegression()
crossvalidation = KFold(n_splits=3, shuffle=True, random_state=1)

baseline = np.mean(cross_val_score(regression, X, y, scoring='r2', cv=crossvalidation))
baseline
# Out:
# 0.5598488578879034
